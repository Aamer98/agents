# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are appointed Chief Resilience Officer for a coastal city of 500,000 people that today faces a 1-in-20-year flood risk which climate projections make likely to become a 1-in-2-year event within 30 years; you have a one-time budget of $1 billion, 20 years to implement interventions, and strong political constraints against both managed retreat and new property taxes, while the city must protect critical infrastructure (hospital, power plant, water treatment) and preserve housing affordability—propose a prioritized, phased 20-year resilience strategy (with timeline and budget allocations) that minimizes expected cumulative social and economic losses over 50 years under uncertainty, and for each major intervention (e.g., hard defenses, green infrastructure, building elevation, zoning changes, targeted buyouts, emergency response upgrades, insurance/subsidy reforms) provide: (a) estimated cost and expected effectiveness at reducing flood damage and frequency of service interruptions, (b) explicit analysis of impacts on equity and housing affordability, (c) key risks and failure modes and how you would monitor, mitigate, and adapt, (d) a clear decision rule with quantitative thresholds for when to escalate to managed retreat or other irreversible actions, and (e) an uncertainty model (scenarios or probability distributions) you used to compare options plus an adaptive evaluation plan that specifies which data to collect in the first 5 years and how those data would update the plan; state all assumptions and show the calculations or logic you used to estimate costs, benefits, and probabilities.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# - City: population 500,000; current 1-in-20-year flood risk. Climate projections imply risk rising to a 1-in-2-year event within ~30 years, with substantial uncertainty about timing and magnitude.
# - Constraint set: one-time budget of $1 billion, 20-year window to implement, no managed retreat, no new property taxes. Must protect critical infrastructure (hospital, power plant, water treatment) and preserve housing affordability; equity considerations are central.
# - Core approach: a layered, phased resilience plan that (i) defends critical infrastructure with targeted hardening, (ii) expands nature-based and urban green infrastructure to reduce runoff, (iii) reduces exposure of housing stock via building elevation and targeted buyouts, (iv) aligns land-use/zoning to curb new risk, (v) upgrades emergency response and resilience financing (insurance/subsidies), and (vi) monitors risk and adapts. The plan emphasizes equity (protecting vulnerable households, avoiding displacement where possible, ensuring affordable housing remains available) and uses a decision framework to escalate to more irreversible actions only under explicit triggers.
#
# - Outcome goal: minimize expected cumulative social and economic losses over 50 years under plausible climate and hazard scenarios, with a transparent, data-driven adaptive evaluation loop.
#
# 1) Assumptions, baseline model, and uncertainty framework (key inputs used for planning calculations)
# - Population and exposure: 500k residents; assume housing/asset exposure is representative of a mid-sized coastal city. We model flood damage using an annual exceedance probability (AEP) framework.
# - Baseline hazard (no intervention): current annual probability of a flood event with damaging impacts is p0 = 0.05 (1-in-20-year). Projections indicate rising risk; we present three scenario trajectories for hazard growth:
#   - Scenario L (Low sensitivity): hazard growth is modest; by year 50, annual probability remains low (p50 ≈ 0.10–0.15).
#   - Scenario M (Moderate): hazard grows to p30 ≈ 0.25 and p50 ≈ 0.40.
#   - Scenario H (High): hazard grows more quickly; p30 ≈ 0.50 and p50 ≈ 0.75.
# - Expected annual damage per flood event: D = $3.0 billion (city-wide average damage per event; conservative mid-range to reflect large but finite exposure). Annual expected damages (EAD) without intervention in year t: EAD_t = p_t × D.
# - Time horizon for evaluation: 50 years of risk, with a 20-year investment window for interventions.
# - Discount rate for present value: 3% real.
# - Interventions are not assumed to indemnify all losses; instead, each intervention reduces EAD by a factor that depends on coverage, vulnerability, and hazard level. We present ranges to reflect uncertainty in effectiveness.
# - Equity and affordability: all measures should avoid large increases in housing costs, preserve affordable housing stock, and ensure benefits accrue broadly (not just to wealthy districts). Buyouts are limited and paired with replacement housing options and relocation support; zoning changes protect affordable rental options where possible.
#
# 2) Overall strategic structure (defense in depth)
# - Hard defenses around critical infrastructure (hospital, power plant, water treatment) to ensure continuity of essential services.
# - Green infrastructure and high-performance urban design to reduce runoff, delay peaks, and overall flood exposure.
# - Residential and commercial exposure reduction by elevating key structures and incentivizing elevation retrofits, with a focus on affordable housing where feasible.
# - Zoning and land-use reforms to prevent long-term growth in flood-prone areas.
# - Targeted buyouts for the highest-risk properties, coupled with affordable relocation and reinvestment options to preserve housing affordability.
# - Emergency response upgrades and resilience financing (including insurance/subsidy reforms) to reduce downtime and cost of recovery.
# - A formal decision framework with predefined triggers that, if reached, would escalate to more irreversible actions (e.g., targeted, large-scale buyouts in additional neighborhoods; if triggers persist, move to a managed retreat approach for the affected areas).
#
# 3) Phased 20-year timeline with budget allocations (phase-based plan)
# One-time budget: $1,000 million (1B) distributed over four 5-year phases.
#
# Phase 1: Years 0–5 (initial implementation; 45–50% of budget)
# - Focus: protect critical infrastructure; establish design and financing structures; start nature-based solutions; begin elevation incentives; establish performance monitoring and data collection.
# - Budget: $510 million
#   - Critical infrastructure hardening (hospital, power plant, water treatment): $300–350M (targeted flood barriers, back-up power, flood doors, pump redundancy, watertight enclosures)
#   - Green infrastructure and nature-based solutions (wetlands, bioswales, permeable pavements, green roofs): $60–110M
#   - Building elevation incentives for targeted housing stock (initial tranche): $60–100M
#   - Emergency response upgrades (backup comms, emergency shelters, mutual aid enhancements): $60–70M
#   - Zoning/land-use policy development and regulatory updates (planning, permitting, staffing): $20–25M
#   - Insurance/subsidy program design and pilot subsidies (municipal reinsurance design, outreach): $5–10M
#   - Contingency and design/engineering risk reserve: ~$20–30M
# - Expected effectiveness (Phase 1):
#   - Critical infrastructure protection: substantial reduction in probability of service interruption for hospital/power/water corridors during moderate-to-strong flood events (target reduction in those facilities’ outage risk ~70–90% for events within protected envelope; city-wide outages reduced by 20–30% during events that would otherwise affect protected zones).
#   - Green infrastructure: early runoff reductions of 10–25% in urban hotspots; delays peak flows by minutes to hours in local basins.
#   - Elevation incentives: early conversion/retrofit for several hundred units with 40–60% reduction in damages for those elevated units; modest effect on overall city EAD but important for key affordable housing blocks.
#   - Emergency response upgrades: faster restoration and improved communications; targeted reductions in service interruption duration by 15–30% in affected neighborhoods.
#   - Zoning updates: groundwork to avoid new residential exposure in high-hazard areas; long-term risk stabilization.
#   - Equity/affordability: dedicated attention to affordable housing; ensure pilots benefit lower-income residents; establish relocation assistance scaffolds for buyouts later.
#
# Phase 2: Years 5–10 (scaling and optimization; 25–30% of budget)
# - Focus: expand green and blue infrastructure; scale building elevation; begin targeted buyouts for very high-risk blocks; begin more aggressive zoning controls; expand emergency response and resilience financing.
# - Budget: $230–$250 million
#   - Green infrastructure expansion (regional and neighborhood-scale projects): $120–$140M
#   - Building elevation program expansion (additional units; assist lower-income households): $60–80M
#   - Targeted buyouts for high-risk neighborhoods (early buyout candidates; relocation and replacement housing support): $50–80M
#   - Emergency response upgrades (additional capacity; regional mutual aid; flood warning systems): $20–30M
#   - Zoning/regulatory updates (implement setbacks, density controls, and incentives for resilient redevelopment): $20–30M
#   - Insurance/subsidy reforms (pilot premium support, public reinsurance mechanisms): $5–10M
# - Expected effectiveness (Phase 2):
#   - Expanded hardening and green infrastructure reduces city-wide EAD further by 10–20% relative to Phase 1 gains.
#   - Elevation program reduces damages for a larger portion of at-risk housing (targeting lower-income and renter households; cumulative city-wide EAD reductions in the 15–25% range from the Phase 2 baseline).
#   - Buyouts begin to meaningfully remove high-risk housing stock, cutting city-wide EAD by 5–15% beyond earlier gains (dependent on chosen neighborhoods and replacement housing options).
#   - Emergency response improvements reduce outages and downtime, further cutting indirect losses.
#
# Phase 3: Years 10–15 (intensification; 15–20% of budget)
# - Focus: intensify buyouts in remaining high-risk zones; implement stronger zoning constraints; adjust building codes and floodproofing requirements; continue to refine financing and resilience subsidies.
# - Budget: $120–$140 million
#   - Targeted buyouts (expanded area and more units): $70–$100M
#   - Zoning and redevelopment controls; enforcement and incentives: $15–$25M
#   - Floodproofing and resilience retrofits for critical corridors and essential facilities: $15–25M
#   - Emergency response enhancements and back-up power for critical facilities: $15–25M
#   - Insurance/subsidy program expansion and evaluation: $5–10M
# - Expected effectiveness:
#   - Buyouts remove additional high-exposure housing; city-wide EAD reductions continue (cumulative reductions in the range of 25–40% versus baseline by year 15, depending on scenario and uptake).
#   - Zoning and redevelopment controls reduce future exposure growth.
#   - Infrastructure resilience investments increase reliability of essential services in flood-prone seasons.
#
# Phase 4: Years 15–20 (assessment, consolidation, and potential irreversible moves; 5–10% of budget)
# - Focus: final adjustments, long-term resilience governance, and a clear decision framework for any irreversible actions; targeted buyouts in remaining exposed zones if warranted by risk, equity constraints, and cost-benefit thresholds; finalize adaptive management plan for the subsequent decades.
# - Budget: $120–$140 million
#   - Final targeted buyouts and relocation support: $60–$80M
#   - Long-term zoning refinement and redevelopment planning: $10–$20M
#   - Final upgrades to critical infrastructure resilience and floodproofing: $20–40M
#   - Final insurance/subsidy reforms and resilience finance structuring: $5–10M
#   - Monitoring and evaluation program continuation: $5–10M
# - Expected effectiveness:
#   - If hazard growth follows moderate trajectory (Scenario M), city-wide EAD is substantially reduced relative to baseline (order of magnitude ~40–60% reduction across 50 years when summed and discounted; exact amounts depend on discounting and uptake). In high-sensitivity scenarios, plan is designed to still avert catastrophic, uncontrolled losses by providing a staged, constrained set of irreversible actions in a controlled, equitable manner.
#
# 4) For each major intervention: (a) cost and effectiveness; (b) equity/housing affordability impacts; (c) risks and failure modes; (d) decision rule and escalations; (e) uncertainty model and adaptive evaluation plan; plus calculations/logical steps used
#
# Intervention A: Hard defenses around critical infrastructure (hospital, power plant, water treatment)
# - (a) Cost and effectiveness
#   - Estimated cost: $300–360 million (Phase 1; potentially $350M total with phased extension in later phases)
#   - Effectiveness: High protection for critical facilities; reduces probability of inundation and service interruption for those facilities by ~70–90% during events within the protected envelope; city-wide outage risk reduced by ~20–30% in events that affect those zones; reduces downtime and critical-care disruption, thereby lowering indirect damages.
# - (b) Equity and housing affordability
#   - Direct benefit disproportionately protects vulnerable populations who rely on hospitals and services; however, the approach must ensure no displacement caused by construction; avoid rising rents near protected zones due to perceived “gated” protection; include community consultation and mitigation for nearby neighborhoods.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: design overruns, construction delays, failure to fully protect due to extreme events, residual groundwater issues.
#   - Mitigation: staged defense design (scalable), independent third-party review, robust drainage, drainage maintenance contracts, continuous monitoring of gate/integrity sensors, contingency budgets.
#   - Monitoring: flood depth sensors near critical facilities; performance audits after every major flood event; quarterly construction oversight; corrosion and mechanical failure checks.
# - (d) Decision rule for escalations
#   - If after 5 years, there remains a >15% annual probability of hospital/power/water facility inundation during 1-in-20-year or more frequent events, trigger a targeted expansion (Phase 2) or escalation to supplement with additional flood barriers or buyouts around adjacent facilities.
#   - If cumulative loss avoidance from this intervention is less than 25% of the projected avoided-loss target after 10 years under a given scenario, escalate to Phase 3 enhancements or reconsider location-based relocations within a defined boundary.
# - (e) Uncertainty model and adaptive plan
#   - Scenarios: L, M, H hazard growth as described.
#   - Model: EAD_t = p_t × D; effectiveness reduces p_t for protected facilities (factor 0.25–0.10 depending on depth/height), with a degrade factor in extreme events.
#   - Adaptive plan: in years 1–5, monitor flood depths at the protected envelope, outage days, and facility downtime. If actual outage days exceed planned by >20% for two consecutive events, adapt by adding modular barriers, additional pumps, or extending protections to remaining critical lines.
# - Assumptions and calculations
#   - D (average event damage) = $3B city-wide.
#   - Protected envelope reduces risk for critical facilities by 80–90% for events that reach those levels; city-wide EAD impact is lower as other areas remain exposed.
#   - PV calculations use r = 3%.
#
# Intervention B: Green infrastructure and nature-based solutions (wetlands, bioswales, permeable surfaces, green roofs)
# - (a) Cost and effectiveness
#   - Cost: Phase 1–2 total $60–110M (Phase 1 around $60–70M; Phase 2 expansion to $50–60M).
#   - Effectiveness: Reduces peak runoff and inland flooding probability modestly; city-wide EAD reductions of ~5–15% in aggregate, with higher benefits in neighborhoods with heavy impermeable surfaces.
# - (b) Equity and housing affordability
#   - Benefits are broadly distributed; reduces flood exposure in historically underserved neighborhoods; creates local green jobs; can improve air quality and urban heat, helping vulnerable residents.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: maintenance of green features; misalignment with drainage utilities; sediment accumulation reducing effectiveness.
#   - Mitigation: long-term maintenance contracts; dedicated operations; performance-based milestones; adapt by retrofitting or adding more green features in hot spots.
#   - Monitoring: groundwater levels, surface runoff, sediment levels, water quality, maintenance completion rates; track flood depth reductions in target neighborhoods.
# - (d) Decision rule
#   - If per-year EAD reductions from green infrastructure fall short of 5% for two consecutive years, reallocate funds to scale other interventions in affected districts or accelerate higher-impact measures (e.g., elevation or buyouts in the affected neighborhoods).
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H with modest to moderate impacts; EAD reduction assumed linearly with project scale and maintenance success.
#   - Adaptive plan: Year 1–5 monitoring of runoff reduction and drainage system performance; adjust design for underperforming hotspots; if adoption rates or maintenance delays exceed 2-year plan, re-evaluate scope and phasing.
#
# Intervention C: Building elevation and retrofits (resilience elevation incentives)
# - (a) Cost and effectiveness
#   - Cost: Phase 1–2 $60–100M (subsidies, subsidies administration, and retrofit costs); Phase 3 expansion if needed; total projected cost around $100–120M.
#   - Effectiveness: For elevated homes, damages reduce by 40–60% depending on depth; city-wide impact moderate (~15–25% additional EAD reduction if a substantial share of elevated homes is in high-exposure zones).
# - (b) Equity and affordability
#   - Targeted to low- and moderate-income households as well as renters in flood-prone blocks; must include affordable replacement housing options; avoid displacement by providing relocation and housing options that maintain or improve affordability.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: structural code compliance, improper elevation leading to residual risk, or uplift in adjacent properties causing new exposures; supply chain for skilled labor.
#   - Mitigation: enforce qualified contractors; provide financing assistance; require insurance adjustments reflecting reduced risk; implement performance-based retrofits; monitor with inspections and post-flood performance checks.
#   - Monitoring: track number of homes elevated, depth of flood protection achieved, claims filed before/after, and any residual damages in elevated structures.
# - (d) Decision rule
#   - If elevation uptake is under 25% of eligible households by year 7 and expected loss reduction is not meeting a 15–20% threshold relative to a no-elevation baseline, reallocate up to 25% of buyout funds to accelerate elevation in the affected blocks.
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H on uptake and effectiveness; adjust incentives (mortgage terms, grants, property-value sharing) to improve uptake if needed.
#   - Adaptive plan: in years 1–5, track elevation installations, occupancy, and flood impact reductions. If uptake lags, adjust eligibility criteria, outreach, and financial incentives to ensure broad participation.
#
# Intervention D: Zoning changes and land-use planning (setbacks, prohibitions on new development in high-risk zones, density controls)
# - (a) Cost and effectiveness
#   - Cost: $20–30M (policy development, staffing, planning operations); mainly administrative but with long-term impacts.
#   - Effectiveness: reduces future exposure growth; modest on a 5–15% range for EAD reductions over a 20-year horizon, depending on enforcement and buy-in from developers and property owners.
# - (b) Equity and affordability
#   - Can limit new development in hazard zones; must ensure affordable housing supply is protected through incentives and replacement housing commitments; protect rental stock and prevent displacement pressure.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: political resistance, legal challenges, noncompliance by developers, leakage (development shifting to other zones).
#   - Mitigation: clear codes, predictable incentives, robust enforcement; incorporate market feedback; ensure exemptions where necessary to prevent negative affordability impacts.
#   - Monitoring: monitor new development permits in hazard zones, occupancy rates, and housing affordability indicators in affected districts.
# - (d) Decision rule
#   - If new permitted density in hazard zones increases exposure or if building permits for hazard-zone projects exceed 5% of new development in a given year, pause and reassess with a targeted buyout or elevation vehicle to reduce future exposure.
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H with varying enforcement effectiveness and market responses; adaptive plan uses annual permit data and housing affordability metrics to adjust zoning and incentives.
#
# Intervention E: Targeted buyouts and relocation for high-risk properties
# - (a) Cost and effectiveness
#   - Cost: $100–180M (Phase 2–3, depending on neighborhoods selected; includes purchase price, relocation stipends, and replacement housing arrangements).
#   - Effectiveness: removes the highest-exposure assets; city-wide EAD reductions from buyouts can reach 30–40% cumulatively across all buyouts, depending on which properties are acquired and what replacement housing is provided.
# - (b) Equity and affordability
#   - Must ensure fair compensation, right of return options if feasible, and a robust relocation support program; emphasize replacement housing that is affordable and accessible to low-income households; mitigate displacement.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: community resistance, political backlash, legal challenges, misalignment of replacement housing with affordability goals, mispricing, or failed integration into replacement neighborhoods.
#   - Mitigation: transparent appraisal processes, community engagement, predictable relocation assistance; ensure that replacement housing is affordable and accessible to affected residents; link to job opportunities where possible.
#   - Monitoring: track number of buyouts completed, relocation outcomes, housing affordability in replacement units, and post-relocation flood exposure of the new neighborhoods.
# - (d) Decision rule
#   - If an identified high-exposure block yields a net present value of avoided losses that exceeds the cost of buyouts by a factor of 2 (or if a neighborhood experiences repeated, multi-year inundation threats with high disruption and equity concerns), trigger expansion of buyouts to adjacent blocks or a larger buyout program.
#   - If buyouts create shortages in replacement housing that would raise rents for remaining residents beyond an affordability threshold, pause further buyouts and reassess with zoning and housing policy adjustments.
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H; probability-weighted outcomes for buyout uptake and replacement housing affordability.
#   - Adaptive plan: establish a 5-year buyout target; if uptake is below target, reallocate resources to incentives (e.g., additional relocation assistance, accelerated resale support) to improve participation. If uptake remains low in the face of high hazard growth, re-evaluate irreversible actions in the targeted zones.
#
# Intervention F: Emergency response upgrades and resilience financing (including insurance/subsidy reforms)
# - (a) Cost and effectiveness
#   - Cost: $60–80M (warning systems, emergency communications, shelters, mutual aid enhancements, municipal reinsurance design; pilot subsidies).
#   - Effectiveness: reduces downtime and service interruptions; improves response times; reduces indirect losses due to delayed recovery; improves hospital and critical facility resilience.
# - (b) Equity and affordability
#   - Benefits all residents; emergency shelters and communications should be accessible to vulnerable populations; ensure sites are accessible by transit and are affordable for residents near hazard zones.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risk: systems failures, cyber threats, insufficient shelter capacity, or underutilization due to planning gaps.
#   - Mitigation: robust redundancy, cybersecurity measures, regular drills, planning for accessibility and mobility for vulnerable residents.
#   - Monitoring: alert times, shelter occupancy, power backup reliability, emergency performance metrics.
# - (d) Decision rule
#   - If emergency response metrics (alert time, shelter readiness, downtime) fail to meet target by year 5–7, scale up investments in warning systems, shelters, and mutual aid capacity in Phase 2–3.
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H; adapt by adjusting training, communications, and shelter placement to ensure optimal coverage; adjust funding if response performance is lagging.
# - (Costs and return) The insurance/subsidy reform program is designed to lower out-of-pocket costs for residents and to incentivize resilience investments by households. It complements other measures and reduces the likelihood of price-driven displacement.
#
# Intervention G: Insurance/subsidy reforms (municipal reinsurance, premium subsidies, resilience grants)
# - (a) Cost and effectiveness
#   - Cost: $5–30M (planning, design, distribution, oversight, risk-sharing arrangements).
#   - Effectiveness: lowers net out-of-pocket costs for residents and incentivizes resilience investments; reduces downward pressure on housing affordability by moderating premium increases.
# - (b) Equity and affordability
#   - Aimed squarely at helping low- and moderate-income households access affordable coverage and resilience funding; helps households stay in place and reduces displacement risk.
# - (c) Risks and failure modes; monitoring/mitigation
#   - Risks: moral hazard (under-investment in resilience) if subsidies reduce incentives; mispricing; governance risk.
#   - Mitigation: tie subsidies to verified resilience investments; sunset subsidies and require compliance with resilience standards; transparent reporting.
#   - Monitoring: premium costs, uptake rates by income group, resilience investment verification.
# - (d) Decision rule
#   - If uptake is low or if subsidies fail to incentivize resilience investments in high-exposure areas, pivot to stricter resilience requirements tied to subsidies (e.g., require elevation, floodproofing, or buyout alternatives for certain areas).
# - (e) Uncertainty model and adaptive plan
#   - Scenarios L/M/H; adapt subsidy terms and conditions to maximize resilience outcomes while protecting affordability.
#
# 5) Decision rules for escalation to managed retreat or irreversible actions
# - The plan uses explicit, quantitative thresholds to escalate irreversible actions (including managed retreat, large-scale relocation) only when outcomes fail to meet defined performance targets under uncertainty.
# - Triggers (example thresholds):
#   - Trigger A (Residence-level risk): If a block or neighborhood continues to experience annualized losses exceeding a pre-set threshold (e.g., EAD_n > $X per year, adjusted for inflation) for two consecutive 5-year periods, despite the full portfolio of interventions, escalate to targeted buyouts or elevation of those blocks, prioritizing equity considerations and replacement housing.
#   - Trigger B (Critical infrastructure failure risk): If risk to critical facilities remains above a defined threshold (e.g., probability of inundation or service interruption in a critical facility exceeds 10% per year for three successive flood seasons), escalate to expanded defenses or buyouts around the block(s) containing the facility if other measures fail to bring risk below threshold.
#   - Trigger C (Cumulative cost threshold): If cumulative investment in resilience approaches a cost threshold where additional resilience investments are less cost-effective than a managed retreat alternative for particular neighborhoods (based on NPV of avoided losses vs. cost of relocation and replacement housing), escalate with a planned, staged retreat for the most exposed blocks.
#   - Trigger D (Affordability threshold): If the combination of zoning changes, buyouts, and subsidies results in a measurable loss of affordable housing stock (or if residents face persistent displacement pressure without feasible replacement options), escalate with a targeted retreat strategy and reinvestment plan for replacement housing in affordable locations.
# - These triggers are evaluated at regular intervals (every 5 years, with interim checks after significant flood events) and are tied to updated risk assessments, actual performance data, and affordability metrics.
#
# 6) Uncertainty model and adaptive evaluation plan (data collection and plan updating)
# - Scenarios:
#   - Scenario L (Low): Hazard growth is modest; p50 remains low to moderate (≈0.1–0.15 by year 50).
#   - Scenario M (Moderate): Hazard increases to p30 ≈ 0.25 and p50 ≈ 0.40; EAD grows accordingly.
#   - Scenario H (High): Hazard grows rapidly; p30 ≈ 0.50 and p50 ≈ 0.75 or higher; EAD increases substantially without interventions.
# - Probability weights (example): L=30%, M=50%, H=20% (these can be refined as part of an ongoing risk assessment process).
# - 50-year evaluation model: EAD_t = p_t × D × (1 − protection_factor_t), where protection_factor_t is the portion of risk reduced by implemented interventions (function of time and phase progress). Net present value of avoided losses is calculated as:
#   NPV_avoided = sum_{t=1}^{50} [EAD_noInterv_t − EAD_withInterv_t] / (1 + r)^t
#   where r = 3%.
# - Adaptive data collection in years 0–5 (first 5 years) to update plan:
#   - Hazard indicators: annual flood frequency data, flood extent maps, depths, and water levels in key basins; new climate and hydrology models; changes in storm surge patterns.
#   - Exposure indicators: updated property values, housing stock at risk, relocation patterns, new development in hazard zones, building code compliance.
#   - Infrastructure indicators: performance of protected facilities during floods, downtime days, pump capacities, drainage performance.
#   - Social indicators: housing affordability metrics, displacement incidents, renter/owner household counts, and equity indicators.
#   - Economic indicators: insurance uptake, premium changes, subsidy usage, and total cost of resilience investments.
# - How data update the plan:
#   - If monitoring shows actual hazard growth is faster than anticipated under a scenario, adjust the emphasis toward more rapid buyouts in high-risk districts or more aggressive elevation/green projects in affected areas.
#   - If affordability is deteriorating due to new zoning or housing supply constraints, adjust by increasing incentives for affordable housing in resilient zones and altering relocation assistance to preserve housing access.
#   - If critical infrastructure resilience underperforms (e.g., higher-than-expected downtime during major events), accelerate additional hardening or expansion of backup systems, or broaden buyouts to protect housing in the most exposed zones.
# - Decision support:
#   - Use a formal decision-support framework (e.g., a resilience risk dashboard) that tracks the underlying indicators and flags when thresholds are crossed. The dashboard informs the phase-level adjustments and triggers for escalation to next steps.
#
# 7) Calculations, logic, and explicit assumptions (summary)
# - Baseline EAD: EAD0 ≈ p0 × D = 0.05 × $3B ≈ $150M/year (undiscounted baseline).
# - Phase-based reductions (illustrative ranges, order-of-magnitude separations):
#   - Hard defenses: reduce city-wide EAD by 20–30% (Phase 1–4) and reduce critical facilities’ outage risk by 70–90% within protected envelopes.
#   - Green infrastructure: add 5–15% city-wide EAD reductions (vary by neighborhood; more in dense urban cores).
#   - Building elevation: 40–60% damage reduction for elevated structures; impacts depend on coverage rate (percentage of exposed housing elevated).
#   - Targeted buyouts: remove 5–40% of exposure in affected blocks over phases, depending on uptake and affordability; higher percentages yield larger EAD reductions but require relocation housing matches.
#   - Zoning changes: reduce future exposure growth; 5–15% city-wide EAD reduction over 20 years depending on enforcement and development patterns.
#   - Emergency response upgrades: reduce downtime and indirect losses by 10–25%.
#   - Insurance/subsidy reforms: reduce net costs to residents by 10–20% (net), which helps affordability and resilience investments.
# - Budget alignment (1B total):
#   - Phase 1 (0–5): ≈ $510M (hard defenses $300–350M; green infra $60–70M; elevation $60–100M; emergency response $60–70M; zoning $20–25M; insurance design $5–10M)
#   - Phase 2 (5–10): ≈ $230–250M (expansion of green infra, elevation, initial buyouts)
#   - Phase 3 (10–15): ≈ $120–140M (expanded buyouts, stronger zoning enforcement, additional resilience upgrades)
#   - Phase 4 (15–20): ≈ $120–140M (final buyouts, consolidation, evaluation, and irreversible actions if required by triggers)
# - Explicit decision thresholds:
#   - Triggers are evaluated at 5-year intervals and after major flood events; if, under any scenario, cumulative losses avoided do not meet target thresholds or if equity/affordability concerns persist, escalate with adaptive changes to phase emphasis, potentially increasing the buyout program or accelerating elevation/retrofitting in the worst-affected districts.
# - Uncertainty handling:
#   - The plan uses explicit hazard scenarios (L/M/H) with probability weights; we use a simple PV-based calculation of avoided losses to compare options and calculate cost-effectiveness using net present value.
#   - The plan uses adaptive management: measurement and updates in years 1–5 and subsequent phases guide reallocation of the $1B budget to maximize expected avoided losses.
#
# 8) Summary of outcomes and rationale
# - The prioritized, phased approach protects critical infrastructure and maintains housing affordability by leveraging a combination of structural defenses, natural and nature-based solutions, targeted elevation, and buyouts only when necessary and appropriately sequenced.
# - Equity and affordability considerations are embedded: elevation and buyouts prioritize low-income households, with strong replacement housing options and relocation support; zoning changes aim to minimize new development in hazard zones while ensuring affordable options elsewhere through incentives.
# - The decision framework provides explicit, quantitative thresholds for escalation to irreversible actions (e.g., managed retreat), guided by ongoing risk assessment and affordability metrics.
# - The adaptive evaluation plan ensures that data collected in the first 5 years (hazard, exposure, infrastructure performance, affordability, and equity indicators) continuously informs reallocation of resources across the remaining phases to maximize expected avoided losses across a 50-year horizon under climate uncertainty.
#
# If you’d like, I can translate this into a more detailed workshop-ready plan with:
# - a phase-by-phase Gantt chart,
# - a per-intervention cost table with ranges,
# - and a simple spreadsheet-ready model for calculating expected avoided losses under the L/M/H scenarios, including discounting and sensitivity tests.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 model_name = "claude-sonnet-4-5"
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       9 display(Markdown(answer))
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1033, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1030 options = self._prepare_options(options)
#    1032 remaining_retries = max_retries - retries_taken
# -> 1033 request = self._build_request(options, retries_taken=retries_taken)
#    1034 self._prepare_request(request)
#    1036 kwargs: HttpxSendArgs = {}
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     503     else:
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#     508 content_type = headers.get("Content-Type")
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     437 custom_headers = options.headers or {}
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#     450 headers = httpx.Headers(headers_dict)
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[10], line 4
#       1 ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
#       2 model_name = "llama3.2"
# ----> 4 response = ollama.chat.completions.create(model=model_name, messages=messages)
#       5 answer = response.choices[0].message.content
#       7 display(Markdown(answer))
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/repos/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "model 'llama3.2' not found", 'type': 'not_found_error', 'param': None, 'code': None}}

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
